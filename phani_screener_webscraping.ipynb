# %% [markdown]
# Agro Chemicals
# Alcoholic Beverages
# Automobile
# Banks
# Cement
# Chemicals
# Construction
# Crude Oil & Natural Gas
# Diamond, Gems and Jewellery
# Edible Oil
# Engineering
# Entertainment
# Fertilizers
# Finance
# Healthcare
# Hotels & Restaurants
# Infrastructure Developers & Operators
# IT - Software
# Mining & Mineral products
# Power Generation & Distribution

# %%
import numpy as np
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')
import time

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
#Agro chemical stocks
mytable_values1 = []
#for i in range(1,10):
#start_time = time.time()
url= 'https://www.screener.in/company/compare/00000001/?limit=50&page=1'
page = requests.get(url,headers = {'User-Agent':'Mozilla/5.0'})
soup=BeautifulSoup(page.content)
table_body=soup.find('table')
for row in table_body.find_all('tr'):
    col=row.find_all('td')
    col=[ele.text.strip() for ele in col]
    mytable_values1.append(col)
    #end_time = time.time()
    #print('Page {} completed in {} seconds'. format(i,end_time-start_time))

# %%
Agro_chem = pd.DataFrame(mytable_values1)

# %%
Agro_chem.dropna(inplace=True)
Agro_chem.columns = ['S.no','Company name','CMP(Rs)', 'P/E','Mark cap/n(Rs.Cr)','Div yeild(%)','Np qtr(Rs.Cr)', 'qtr profit(%)','Sales qtr(Rs.Cr)','qtr sales var(%)','ROCE(%)']
Agro_chem.insert(0, 'Sector', 'Agro Chemical')
del Agro_chem['S.no']

# %%
Agro_chem
# Out:
#            Sector      Company name   CMP(Rs)    P/E Mark cap/n(Rs.Cr)  \
# 1   Agro Chemical               UPL    663.90  12.56          50740.04
# 2   Agro Chemical    P I Industries   2994.25  49.44          45435.00
# 3   Agro Chemical   Sumitomo Chemi.    508.05  54.43          25364.16
# 4   Agro Chemical   Bayer Crop Sci.   4648.25  32.03          20887.32
# 5   Agro Chemical    Bharat Rasayan  10899.15  25.26           4534.33
# 6   Agro Chemical  Astec Lifescienc   2145.60  47.96           4233.81
# 7   Agro Chemical      Rallis India    211.45  27.60           4108.18
# 8   Agro Chemical   Sharda Cropchem    434.75  11.79           3936.78
# 9   Agro Chemical  India Pesticides    284.45  20.75           3273.59
# 10  Agro Chemical  Dhanuka Agritech    684.70  15.27           3198.30
# 11  Agro Chemical     Best Agrolife   1303.45  25.92           3083.36
# 12  Agro Chemical  Meghmani Organi.    116.65   8.70           2961.59
# ...

# %%
#Alcoholic beverages stocks
mytable_values2 = []
url= 'https://www.screener.in/company/compare/00000003/?limit=50&page=1'
page = requests.get(url,headers = {'User-Agent':'Mozilla/5.0'})
soup=BeautifulSoup(page.content)
table_body=soup.find('table')
for row in table_body.find_all('tr'):
    col=row.find_all('td')
    col=[ele.text.strip() for ele in col]
    mytable_values2.append(col)

# %%
Alco_stocks = pd.DataFrame(mytable_values2)

# %%
Alco_stocks.dropna(inplace=True)
Alco_stocks.columns = ['S.no','Company name','CMP(Rs)', 'P/E','Mark cap/n(Rs.Cr)','Div yeild(%)','Np qtr(Rs.Cr)', 'qtr profit(%)','Sales qtr(Rs.Cr)','qtr sales var(%)','ROCE(%)']
Alco_stocks.insert(0, 'Sector', 'Alcoholic Beverages')
del Alco_stocks['S.no']

# %%
Alco_stocks
# Out:
#                  Sector      Company name  CMP(Rs)    P/E Mark cap/n(Rs.Cr)  \
# 1   Alcoholic Beverages    United Spirits   827.15  52.68          60085.98
# 2   Alcoholic Beverages  United Breweries  1654.90  88.11          43755.56
# 3   Alcoholic Beverages    Radico Khaitan  1062.85  56.68          14204.12
# 4   Alcoholic Beverages    Globus Spirits   835.55  14.23           2403.48
# 5   Alcoholic Beverages  Tilaknagar Inds.   100.70  51.44           1679.06
# 6   Alcoholic Beverages     G M Breweries   592.70  10.99           1085.13
# 7   Alcoholic Beverages    Assoc.Alcohols   471.15  13.30            852.07
# 8   Alcoholic Beverages  Som Distilleries   119.30  29.37            834.60
# 9   Alcoholic Beverages    IFB Agro Inds.   553.20   9.21            516.28
# 10  Alcoholic Beverages    Piccadily Agro    40.90  15.84            385.85
# 11  Alcoholic Beverages    Jagatjit Inds.    63.35                   292.36
# ...

# %%
#Automobile Stocks
mytable_values3 = []
url= 'https://www.screener.in/company/compare/00000005/?limit=50&page=1'
page = requests.get(url,headers = {'User-Agent':'Mozilla/5.0'})
soup=BeautifulSoup(page.content)
table_body=soup.find('table')
for row in table_body.find_all('tr'):
    col=row.find_all('td')
    col=[ele.text.strip() for ele in col]
    mytable_values3.append(col)

# %%
Auto_stock = pd.DataFrame(mytable_values3)

# %%
Auto_stock.dropna(inplace=True)
Auto_stock.columns = ['S.no','Company name','CMP(Rs)', 'P/E','Mark cap/n(Rs.Cr)','Div yeild(%)','Np qtr(Rs.Cr)', 'qtr profit(%)','Sales qtr(Rs.Cr)','qtr sales var(%)','ROCE(%)']
Auto_stock.insert(0, 'Sector', 'Automobile')
del Auto_stock['S.no']

# %%
Auto_stock
# Out:
#         Sector      Company name  CMP(Rs)     P/E Mark cap/n(Rs.Cr)  \
# 1   Automobile     Maruti Suzuki  8649.55   58.84         261308.16
# 2   Automobile             M & M  1248.20   19.33         155131.79
# 3   Automobile       Tata Motors   399.00                 142388.21
# 4   Automobile        Bajaj Auto  3604.80   18.96         104319.66
# 5   Automobile     Eicher Motors  3471.20   46.34          94994.75
# 6   Automobile     TVS Motor Co.  1077.60   48.97          51192.07
# 7   Automobile     Hero Motocorp  2546.45   19.23          50888.72
# 8   Automobile     Ashok Leyland   147.10  565.61          43190.44
# 9   Automobile    Escorts Kubota  1999.75   37.80          26366.47
# 10  Automobile   Tata Motors-DVR   193.70                   9849.70
# 11  Automobile  Olectra Greentec   601.55   94.52           4938.79
# 12  Automobile  VST Till. Tract.  2183.65   22.10           1886.01
# 13  Automobile      Force Motors  1331.70                   1754.77
# ...

# %%
#Banking stocks
mytable_values4 = []
url= 'https://www.screener.in/company/compare/00000006/?limit=50&page=1'
page = requests.get(url,headers = {'User-Agent':'Mozilla/5.0'})
soup=BeautifulSoup(page.content)
table_body=soup.find('table')
for row in table_body.find_all('tr'):
    col=row.find_all('td')
    col=[ele.text.strip() for ele in col]
    mytable_values4.append(col)

# %%
Bank_stock = pd.DataFrame(mytable_values4)

# %%
Bank_stock.dropna(inplace=True)
Bank_stock.columns = ['S.no','Company name','CMP(Rs)', 'P/E','Mark cap/n(Rs.Cr)','Div yeild(%)','Np qtr(Rs.Cr)', 'qtr profit(%)','Sales qtr(Rs.Cr)','qtr sales var(%)','ROCE(%)']
Bank_stock.insert(0, 'Sector', 'Banking')
del Bank_stock['S.no']

# %%
Bank_stock
# Out:
#      Sector      Company name  CMP(Rs)    P/E Mark cap/n(Rs.Cr) Div yeild(%)  \
# 1   Banking         HDFC Bank  1393.60  19.55         776449.79         1.11
# 2   Banking        ICICI Bank   853.60  21.47         595304.31         0.59
# 3   Banking    St Bk of India   521.45  11.48         465243.14         1.36
# 4   Banking   Kotak Mah. Bank  1801.50  27.43         357681.36         0.06
# 5   Banking         Axis Bank   802.00  15.27         246497.96         0.12
# 6   Banking     IndusInd Bank  1184.25  17.55          91943.52         0.72
# 7   Banking    Bank of Baroda   130.00   7.81          67227.71         2.19
# 8   Banking         IDBI Bank    42.65  16.94          45806.94         0.00
# 9   Banking      Bandhan Bank   264.25  66.65          42605.71         0.00
# 10  Banking       Canara Bank   223.50   5.16          40545.81         2.91
# 11  Banking          Yes Bank    15.80  33.84          39588.20         0.00
# ...

# %%
#Electrical equipment stocks
mytable_values5 = []
url= 'https://www.screener.in/company/compare/00000008/?limit=50&page=1'
page = requests.get(url,headers = {'User-Agent':'Mozilla/5.0'})
soup=BeautifulSoup(page.content)
table_body=soup.find('table')
for row in table_body.find_all('tr'):
    col=row.find_all('td')
    col=[ele.text.strip() for ele in col]
    mytable_values5.append(col)

# %%
Ele_Equip = pd.DataFrame(mytable_values5)

# %%
Ele_Equip.dropna(inplace=True)
Ele_Equip.columns = ['S.no','Company name','CMP(Rs)', 'P/E','Mark cap/n(Rs.Cr)','Div yeild(%)','Np qtr(Rs.Cr)', 'qtr profit(%)','Sales qtr(Rs.Cr)','qtr sales var(%)','ROCE(%)']
Ele_Equip.insert(0, 'Sector', 'Electrical Equipment')
del Ele_Equip['S.no']

# %%
Ele_Equip
# Out:
#                   Sector      Company name  CMP(Rs)     P/E Mark cap/n(Rs.Cr)  \
# 1   Electrical Equipment           Siemens  2740.05   80.50          97585.78
# 2   Electrical Equipment     Havells India  1230.95   64.06          77123.04
# 3   Electrical Equipment             A B B  3265.85  122.20          69208.22
# 4   Electrical Equipment  CG Power & Indu.   256.65   74.59          39131.09
# 5   Electrical Equipment  Crompton Gr. Con   383.85   38.91          24433.69
# 6   Electrical Equipment           B H E L    60.65   29.93          21118.71
# 7   Electrical Equipment    Hitachi Energy  3396.55  117.74          14420.76
# 8   Electrical Equipment  V-Guard Industri   250.95   42.30          10837.33
# 9   Electrical Equipment       K E C Intl.   419.20   31.76          10765.53
# 10  Electrical Equipment   Triveni Turbine   257.50   59.68           8318.87
# 11  Electrical Equipment     Suzlon Energy     6.80                   8229.46
# ...

# %%
#cement stocks
mytable_values6 = []
url= 'https://www.screener.in/company/compare/00000011/?limit=50&page=1'
page = requests.get(url,headers = {'User-Agent':'Mozilla/5.0'})
soup=BeautifulSoup(page.content)
table_body=soup.find('table')
for row in table_body.find_all('tr'):
    col=row.find_all('td')
    col=[ele.text.strip() for ele in col]
    mytable_values6.append(col)

# %%
Cement_stock = pd.DataFrame(mytable_values6)

# %%
Cement_stock.dropna(inplace=True)
Cement_stock.columns = ['S.no','Company name','CMP(Rs)', 'P/E','Mark cap/n(Rs.Cr)','Div yeild(%)','Np qtr(Rs.Cr)', 'qtr profit(%)','Sales qtr(Rs.Cr)','qtr sales var(%)','ROCE(%)']
Cement_stock.insert(0, 'Sector', 'Cement')
del Cement_stock['S.no']

# %%
Cement_stock
# Out:
#     Sector      Company name   CMP(Rs)     P/E Mark cap/n(Rs.Cr) Div yeild(%)  \
# 1   Cement    UltraTech Cem.   6181.75   24.74         178472.88         0.61
# 2   Cement    Ambuja Cements    496.85   40.85          98676.31         1.27
# 3   Cement      Shree Cement  21075.65   38.40          76070.22         0.43
# 4   Cement               ACC   2253.90   30.35          42334.50         2.57
# 5   Cement  Dalmia BharatLtd   1506.40   26.12          28219.88         0.60
# 6   Cement       J K Cements   2508.25   29.83          19385.41         0.60
# 7   Cement  The Ramco Cement    702.30   19.86          16601.83         0.43
# 8   Cement     Nuvoco Vistas    398.35                  14220.19         0.00
# 9   Cement     India Cements    236.15   63.33           7316.76         0.42
# 10  Cement      Birla Corpn.    904.10   19.85           6957.85         1.11
# 11  Cement   JK Lakshmi Cem.    544.65   13.88           6409.48         0.92
# ...

# %%
#Chemical stocks
mytable_values7 = []
url= 'https://www.screener.in/company/compare/00000014/?limit=50&page=1'
page = requests.get(url,headers = {'User-Agent':'Mozilla/5.0'})
soup=BeautifulSoup(page.content)
table_body=soup.find('table')
for row in table_body.find_all('tr'):
    col=row.find_all('td')
    col=[ele.text.strip() for ele in col]
    mytable_values7.append(col)

# %%
Chem_stock = pd.DataFrame(mytable_values7)

# %%
Chem_stock.dropna(inplace=True)
Chem_stock.columns = ['S.no','Company name','CMP(Rs)', 'P/E','Mark cap/n(Rs.Cr)','Div yeild(%)','Np qtr(Rs.Cr)', 'qtr profit(%)','Sales qtr(Rs.Cr)','qtr sales var(%)','ROCE(%)']
Chem_stock.insert(0, 'Sector', 'Chemical')
del Chem_stock['S.no']

# %%
Chem_stock
# Out:
#       Sector      Company name  CMP(Rs)     P/E Mark cap/n(Rs.Cr)  \
# 1   Chemical    Pidilite Inds.  2621.60   99.39         133288.29
# 2   Chemical               SRF  2496.85   35.22          74012.84
# 3   Chemical  Gujarat Fluoroch  3986.35   47.15          43756.85
# 4   Chemical  Solar Industries  3827.25   67.43          34657.08
# 5   Chemical    Deepak Nitrite  2225.45   30.41          30369.96
# 6   Chemical    Tata Chemicals  1151.85   18.74          29344.53
# 7   Chemical  Aarti Industries   781.85   21.29          28338.71
# 8   Chemical       Linde India  3173.05   72.45          27088.61
# 9   Chemical              Atul  8763.20   43.07          25896.10
# 10  Chemical  Navin Fluo.Intl.  4600.50   80.92          22789.20
# 11  Chemical      Fine Organic  7072.45   56.54          21684.43
# 12  Chemical   Vinati Organics  1979.10   55.45          20347.26
# 13  Chemical     Clean Science  1613.00   70.02          17115.64
# ...

# %%
#Construction stocks
mytable_values8 = []
url= 'https://www.screener.in/company/compare/00000016/?limit=50&page=1'
page = requests.get(url,headers = {'User-Agent':'Mozilla/5.0'})
soup=BeautifulSoup(page.content)
table_body=soup.find('table')
for row in table_body.find_all('tr'):
    col=row.find_all('td')
    col=[ele.text.strip() for ele in col]
    mytable_values8.append(col)

# %%
Construc_stock = pd.DataFrame(mytable_values8)

# %%
Construc_stock.dropna(inplace=True)
Construc_stock.columns = ['S.no','Company name','CMP(Rs)', 'P/E','Mark cap/n(Rs.Cr)','Div yeild(%)','Np qtr(Rs.Cr)', 'qtr profit(%)','Sales qtr(Rs.Cr)','qtr sales var(%)','ROCE(%)']
Construc_stock.insert(0, 'Sector', 'Construction')
del Construc_stock['S.no']

# %%
Construc_stock
# Out:
#           Sector      Company name  CMP(Rs)     P/E Mark cap/n(Rs.Cr)  \
# 1   Construction  Macrotech Devel.   989.80   36.23          47548.72
# 2   Construction  National Standar  5063.60  655.06          10127.20
# 3   Construction        Rail Vikas    36.80    6.15           7672.87
# 4   Construction     PNC Infratech   263.55    9.59           6758.53
# 5   Construction    Mahindra Life.   431.35   54.76           6692.58
# 6   Construction    KNR Construct.   221.90   18.53           6229.46
# 7   Construction               NCC    69.15   11.14           4338.45
# 8   Construction  H.G. Infra Engg.   559.55    9.35           3632.90
# 9   Construction    Ganesh Housing   382.80   40.82           3195.33
# 10  Construction         Man Infra    82.50   13.80           3070.06
# 11  Construction     JP Associates    11.40                   2800.61
# 12  Construction      PSP Projects   634.65   13.79           2285.63
# ...

# %%
#Crude Oil & Natural Gas stocks
mytable_values9 = []
url= 'https://www.screener.in/company/compare/00000019/?limit=50&page=1'
page = requests.get(url,headers = {'User-Agent':'Mozilla/5.0'})
soup=BeautifulSoup(page.content)
table_body=soup.find('table')
for row in table_body.find_all('tr'):
    col=row.find_all('td')
    col=[ele.text.strip() for ele in col]
    mytable_values9.append(col)

# %%
Crude_stock = pd.DataFrame(mytable_values9)

# %%
Crude_stock.dropna(inplace=True)
Crude_stock.columns = ['S.no','Company name','CMP(Rs)', 'P/E','Mark cap/n(Rs.Cr)','Div yeild(%)','Np qtr(Rs.Cr)', 'qtr profit(%)','Sales qtr(Rs.Cr)','qtr sales var(%)','ROCE(%)']
Crude_stock.insert(0, 'Sector', 'Crude Oil & Natural Gas stocks')
del Crude_stock['S.no']

# %%
Crude_stock
# Out:
#                            Sector      Company name CMP(Rs)    P/E  \
# 1  Crude Oil & Natural Gas stocks           O N G C  129.85   3.28
# 2  Crude Oil & Natural Gas stocks         Oil India  189.05   2.78
# 3  Crude Oil & Natural Gas stocks  Hind.Oil Explor.  134.40  23.69
# 4  Crude Oil & Natural Gas stocks  Selan Expl. Tech  315.85  27.60
# 5  Crude Oil & Natural Gas stocks     Aban Offshore   50.55
# 6  Crude Oil & Natural Gas stocks      Asian Energy   71.50  28.19
#
#   Mark cap/n(Rs.Cr) Div yeild(%) Np qtr(Rs.Cr) qtr profit(%) Sales qtr(Rs.Cr)  \
# 1         163292.77         8.09       8580.75         48.80        182893.75
# 2          20511.58         7.54       3230.23        166.01         11566.93
# 3           1779.29         0.00         32.35        191.44            89.42
# 4            478.59         1.58          9.08        443.71            30.12
# 5            294.75         0.00       -212.87         19.93           239.01
# ...

# %%
#Diamond, Gems and Jewellery
mytable_values10 = []
url= 'https://www.screener.in/company/compare/00000020/?limit=50&page=1'
page = requests.get(url,headers = {'User-Agent':'Mozilla/5.0'})
soup=BeautifulSoup(page.content)
table_body=soup.find('table')
for row in table_body.find_all('tr'):
    col=row.find_all('td')
    col=[ele.text.strip() for ele in col]
    mytable_values10.append(col)

# %%
Jewel_stock = pd.DataFrame(mytable_values10)

# %%
Jewel_stock.dropna(inplace=True)
Jewel_stock.columns = ['S.no','Company name','CMP(Rs)', 'P/E','Mark cap/n(Rs.Cr)','Div yeild(%)','Np qtr(Rs.Cr)', 'qtr profit(%)','Sales qtr(Rs.Cr)','qtr sales var(%)','ROCE(%)']
Jewel_stock.insert(0, 'Sector', 'Diamond, Gems and Jewellery')
del Jewel_stock['S.no']

# %%
Jewel_stock
# Out:
#                          Sector      Company name  CMP(Rs)      P/E  \
# 1   Diamond, Gems and Jewellery     Titan Company  2598.65    77.65
# 2   Diamond, Gems and Jewellery    Rajesh Exports   672.70    19.83
# 3   Diamond, Gems and Jewellery  Kalyan Jewellers   101.00    27.16
# 4   Diamond, Gems and Jewellery    Vaibhav Global   345.25    35.15
# 5   Diamond, Gems and Jewellery       PC Jeweller    97.00
# 6   Diamond, Gems and Jewellery  Thangamayil Jew.  1269.60    26.92
# 7   Diamond, Gems and Jewellery     Goldiam Intl.   125.60    13.39
# 8   Diamond, Gems and Jewellery    Asian Star Co.   735.05    12.07
# 9   Diamond, Gems and Jewellery   Renaiss. Global   110.20     9.84
# 10  Diamond, Gems and Jewellery    D. P. Abhushan   387.55    17.57
# 11  Diamond, Gems and Jewellery             T B Z    79.30    16.31
# 12  Diamond, Gems and Jewellery  Starlineps Enter   110.20  1221.53
# 13  Diamond, Gems and Jewellery  Radhika Jeweltec   160.05    10.95
# ...

# %%
#Edible Oil
mytable_values11 = []
url= 'https://www.screener.in/company/compare/00000023/?limit=50&page=1'
page = requests.get(url,headers = {'User-Agent':'Mozilla/5.0'})
soup=BeautifulSoup(page.content)
table_body=soup.find('table')
for row in table_body.find_all('tr'):
    col=row.find_all('td')
    col=[ele.text.strip() for ele in col]
    mytable_values11.append(col)

# %%
Edoil_stock = pd.DataFrame(mytable_values11)

# %%
Edoil_stock.dropna(inplace=True)
Edoil_stock.columns = ['S.no','Company name','CMP(Rs)', 'P/E','Mark cap/n(Rs.Cr)','Div yeild(%)','Np qtr(Rs.Cr)', 'qtr profit(%)','Sales qtr(Rs.Cr)','qtr sales var(%)','ROCE(%)']
Edoil_stock.insert(0, 'Sector', 'Edible Oil')
del Edoil_stock['S.no']

# %%
Edoil_stock
# Out:
#         Sector      Company name  CMP(Rs)     P/E Mark cap/n(Rs.Cr)  \
# 1   Edible Oil      Adani Wilmar   683.80  109.63          88859.47
# 2   Edible Oil   Patanjali Foods  1376.35   57.03          49848.02
# 3   Edible Oil   Guj. Ambuja Exp   264.15   12.76           6077.24
# 4   Edible Oil  Agro Tech Foods.   718.10  102.70           1749.04
# 5   Edible Oil  AVT Natural Prod   103.15   19.30           1570.22
# 6   Edible Oil  Manorama Indust.  1286.95   59.79           1528.94
# 7   Edible Oil        Gokul Agro    81.70    8.54           1171.03
# 8   Edible Oil    BCL Industries   323.45    9.13            782.21
# 9   Edible Oil   Vegetable Prod.    53.90                    588.59
# 10  Edible Oil   Mangalam Global    35.10  359.62            456.72
# 11  Edible Oil  KN Agri Resource   174.15    9.23            435.36
# 12  Edible Oil       Ajanta Soya    42.95    7.77            345.67
# 13  Edible Oil      Vijay Solvex  1046.45    7.32            335.13
# ...

# %%
#Engineering company stocks
mytable_values12 = []
url= 'https://www.screener.in/company/compare/00000072/?limit=50&page=1'
page = requests.get(url,headers = {'User-Agent':'Mozilla/5.0'})
soup=BeautifulSoup(page.content)
table_body=soup.find('table')
for row in table_body.find_all('tr'):
    col=row.find_all('td')
    col=[ele.text.strip() for ele in col]
    mytable_values12.append(col)

# %%
Engi_stock = pd.DataFrame(mytable_values12)

# %%
Engi_stock.dropna(inplace=True)
Engi_stock.columns = ['S.no','Company name','CMP(Rs)', 'P/E','Mark cap/n(Rs.Cr)','Div yeild(%)','Np qtr(Rs.Cr)', 'qtr profit(%)','Sales qtr(Rs.Cr)','qtr sales var(%)','ROCE(%)']
Engi_stock.insert(0, 'Sector', 'Engineering')
del Engi_stock['S.no']

# %%
Engi_stock
# Out:
#          Sector      Company name   CMP(Rs)     P/E Mark cap/n(Rs.Cr)  \
# 1   Engineering  Lak. Mach. Works  12034.25   48.80          12847.23
# 2   Engineering  Sterling & Wils.    292.20                   5544.67
# 3   Engineering  MTAR Technologie   1577.90   70.81           4858.39
# 4   Engineering     Paras Defence    641.55   74.81           2503.21
# 5   Engineering       Thejo Engg.   1035.10   29.26           1105.79
# 6   Engineering               HMT     29.60    1.96           1059.68
# 7   Engineering       Forbes & Co    713.80    0.20            920.80
# 8   Engineering  The Anup Enginee    896.50   14.71            887.31
# 9   Engineering           Skipper     70.80   19.11            728.98
# 10  Engineering      Singer India     72.40   46.52            388.90
# 11  Engineering      Macpower CNC    380.05   27.12            380.21
# 12  Engineering  ICE Make Refrig.    238.35   33.46            376.11
# ...

# %%
#Entertainment stocks
mytable_values13 = []
url= 'https://www.screener.in/company/compare/00000024/?limit=50&page=1'
page = requests.get(url,headers = {'User-Agent':'Mozilla/5.0'})
soup=BeautifulSoup(page.content)
table_body=soup.find('table')
for row in table_body.find_all('tr'):
    col=row.find_all('td')
    col=[ele.text.strip() for ele in col]
    mytable_values13.append(col)

# %%
Ente_stock = pd.DataFrame(mytable_values13)

# %%
Ente_stock.dropna(inplace=True)
Ente_stock.columns = ['S.no','Company name','CMP(Rs)', 'P/E','Mark cap/n(Rs.Cr)','Div yeild(%)','Np qtr(Rs.Cr)', 'qtr profit(%)','Sales qtr(Rs.Cr)','qtr sales var(%)','ROCE(%)']
Ente_stock.insert(0, 'Sector', 'Entertainment')
del Ente_stock['S.no']

# %%
Ente_stock
# Out:
#            Sector      Company name  CMP(Rs)     P/E Mark cap/n(Rs.Cr)  \
# 1   Entertainment  Zee Entertainmen   273.15   27.98          26187.72
# 2   Entertainment    Sun TV Network   537.35   11.96          21172.21
# 3   Entertainment               PVR  1698.90                  10385.76
# 4   Entertainment    Saregama India   377.60   43.81           7297.98
# 5   Entertainment    TV18 Broadcast    36.95   12.20           6326.12
# 6   Entertainment      Inox Leisure   500.85                   6130.40
# 7   Entertainment        Delta Corp   214.25   22.96           5732.64
# 8   Entertainment     Dish TV India    16.65    4.14           3065.74
# 9   Entertainment     Hathway Cable    16.15   22.71           2858.72
# 10  Entertainment       Prime Focus    75.00                   2225.83
# 11  Entertainment  Wonderla Holiday   372.05   30.89           2105.44
# 12  Entertainment   Tips Industries  1549.45   26.55           2008.28
# ...

# %%
#Fertilizer stocks
mytable_values14 = []
url= 'https://www.screener.in/company/compare/00000025/?limit=50&page=1'
page = requests.get(url,headers = {'User-Agent':'Mozilla/5.0'})
soup=BeautifulSoup(page.content)
table_body=soup.find('table')
for row in table_body.find_all('tr'):
    col=row.find_all('td')
    col=[ele.text.strip() for ele in col]
    mytable_values14.append(col)

# %%
Ferti_stock = pd.DataFrame(mytable_values14)

# %%
Ferti_stock.dropna(inplace=True)
Ferti_stock.columns = ['S.no','Company name','CMP(Rs)', 'P/E','Mark cap/n(Rs.Cr)','Div yeild(%)','Np qtr(Rs.Cr)', 'qtr profit(%)','Sales qtr(Rs.Cr)','qtr sales var(%)','ROCE(%)']
Ferti_stock.insert(0, 'Sector', 'Fertilizer')
del Ferti_stock['S.no']

# %%
Ferti_stock
# Out:
#         Sector      Company name CMP(Rs)     P/E Mark cap/n(Rs.Cr)  \
# 1   Fertilizer  Coromandel Inter  969.90   16.87          28504.93
# 2   Fertilizer     Chambal Fert.  318.45    8.68          13254.14
# 3   Fertilizer           G N F C  662.95    5.07          10306.72
# 4   Fertilizer           F A C T  114.75   13.78           7434.65
# 5   Fertilizer  Paradeep Phospha   64.00   12.94           5212.79
# 6   Fertilizer           G S F C  128.75    4.62           5124.42
# 7   Fertilizer             R C F   92.50    6.43           5105.82
# 8   Fertilizer   Natl.Fertilizer   48.05   18.85           2352.38
# 9   Fertilizer    M B Agro Prod.  909.70   25.75           1992.86
# 10  Fertilizer   Mangalore Chem.  127.80   17.56           1515.89
# 11  Fertilizer           S P I C   53.55    5.51           1090.49
# 12  Fertilizer  Krishana Phosch.  343.35   34.99           1017.65
# 13  Fertilizer  Madras Fertilize   49.80    4.01            803.08
# ...

# %%
#Finance stocks
mytable_values14 = []
url= 'https://www.screener.in/company/compare/00000026/?limit=50&page=1'
page = requests.get(url,headers = {'User-Agent':'Mozilla/5.0'})
soup=BeautifulSoup(page.content)
table_body=soup.find('table')
for row in table_body.find_all('tr'):
    col=row.find_all('td')
    col=[ele.text.strip() for ele in col]
    mytable_values14.append(col)

# %%
Fin_stock = pd.DataFrame(mytable_values14)

# %%
Fin_stock.dropna(inplace=True)
Fin_stock.columns = ['S.no','Company name','CMP(Rs)', 'P/E','Mark cap/n(Rs.Cr)','Div yeild(%)','Np qtr(Rs.Cr)', 'qtr profit(%)','Sales qtr(Rs.Cr)','qtr sales var(%)','ROCE(%)']
Fin_stock.insert(0, 'Sector', 'Finance')
del Fin_stock['S.no']

# %%
Fin_stock
# Out:
#      Sector      Company name  CMP(Rs)    P/E Mark cap/n(Rs.Cr) Div yeild(%)  \
# 1   Finance     Bajaj Finance  7151.65  50.24         433173.62         0.28
# 2   Finance           H D F C  2283.25  18.14         414725.80         1.31
# 3   Finance     Bajaj Finserv  1681.75  53.23         267911.26         0.02
# 4   Finance         SBI Cards   861.30  41.99          81398.83         0.29
# 5   Finance    Bajaj Holdings  6651.85  17.43          74023.99         1.73
# 6   Finance  Cholaman.Inv.&Fn   724.65  24.95          59564.08         0.28
# 7   Finance   Muthoot Finance  1020.20  10.83          40976.43         1.96
# 8   Finance          HDFC AMC  1920.20  30.08          40958.36         2.19
# 9   Finance    Shriram Trans.  1189.00   9.15          32178.07         1.68
# 10  Finance           I R F C    21.40   4.48          27966.60         6.54
# 11  Finance  Power Fin.Corpn.   101.95   1.93          26902.52        11.77
# ...

# %%
#Health care stocks
mytable_values15 = []
url= 'https://www.screener.in/company/compare/00000030/?limit=50&page=1'
page = requests.get(url,headers = {'User-Agent':'Mozilla/5.0'})
soup=BeautifulSoup(page.content)
table_body=soup.find('table')
for row in table_body.find_all('tr'):
    col=row.find_all('td')
    col=[ele.text.strip() for ele in col]
    mytable_values15.append(col)

# %%
Health_stock = pd.DataFrame(mytable_values15)

# %%
Health_stock.dropna(inplace=True)
Health_stock.columns = ['S.no','Company name','CMP(Rs)', 'P/E','Mark cap/n(Rs.Cr)','Div yeild(%)','Np qtr(Rs.Cr)', 'qtr profit(%)','Sales qtr(Rs.Cr)','qtr sales var(%)','ROCE(%)']
Health_stock.insert(0, 'Sector', 'Health care')
del Health_stock['S.no']

# %%
Health_stock
# Out:
#          Sector      Company name  CMP(Rs)    P/E Mark cap/n(Rs.Cr)  \
# 1   Health care  Apollo Hospitals  4266.05  69.40          61314.94
# 2   Health care    Max Healthcare   429.15  65.20          41598.87
# 3   Health care    Fortis Health.   272.85  50.48          20618.14
# 4   Health care   Dr Lal Pathlabs  2358.80  72.43          19651.23
# 5   Health care  Narayana Hrudaya   714.40  38.77          14590.10
# 6   Health care  Aster DM Health.   237.75  21.56          11860.92
# 7   Health care  Krishna Institu.  1462.85  37.21          11668.58
# 8   Health care     Poly Medicure   962.25  68.08           9250.35
# 9   Health care  Metropolis Healt  1584.85  46.98           8113.71
# 10  Health care    Rainbow Child.   635.75  46.84           6453.47
# 11  Health care  Vijaya Diagnost.   420.35  45.61           4294.75
# 12  Health care     Health.Global   295.90                  4117.50
# 13  Health care   Thyrocare Tech.   674.10  28.77           3556.50
# ...

# %%
#Hotels & Restaurant stocks
mytable_values16 = []
url= 'https://www.screener.in/company/compare/00000031/?limit=50&page=1'
page = requests.get(url,headers = {'User-Agent':'Mozilla/5.0'})
soup=BeautifulSoup(page.content)
table_body=soup.find('table')
for row in table_body.find_all('tr'):
    col=row.find_all('td')
    col=[ele.text.strip() for ele in col]
    mytable_values16.append(col)

# %%
Hotel_stock = pd.DataFrame(mytable_values16)

# %%
Hotel_stock.dropna(inplace=True)
Hotel_stock.columns = ['S.no','Company name','CMP(Rs)', 'P/E','Mark cap/n(Rs.Cr)','Div yeild(%)','Np qtr(Rs.Cr)', 'qtr profit(%)','Sales qtr(Rs.Cr)','qtr sales var(%)','ROCE(%)']
Hotel_stock.insert(0, 'Sector', 'Hotels and Restaurants')
del Hotel_stock['S.no']

# %%
Hotel_stock
# Out:
#                     Sector      Company name  CMP(Rs)     P/E  \
# 1   Hotels and Restaurants  Indian Hotels Co   317.15  221.79
# 2   Hotels and Restaurants               EIH   184.55  318.71
# 3   Hotels and Restaurants     Chalet Hotels   390.00
# 4   Hotels and Restaurants  Lemon Tree Hotel    85.80
# 5   Hotels and Restaurants  Mahindra Holiday   272.85   46.48
# 6   Hotels and Restaurants   Barbeque-Nation  1052.55  126.85
# 7   Hotels and Restaurants           I T D C   342.60  168.38
# 8   Hotels and Restaurants  EIH Assoc.Hotels   450.60   47.75
# 9   Hotels and Restaurants   Oriental Hotels    76.50  116.75
# 10  Hotels and Restaurants     TajGVK Hotels   189.25   34.69
# 11  Hotels and Restaurants  Speciality Rest.   209.55   30.97
# 12  Hotels and Restaurants  Royal Orch.Hotel   267.95   32.42
# 13  Hotels and Restaurants     Sayaji Hotels   374.50   32.47
# 14  Hotels and Restaurants               HLV     9.65
# ...

# %%
#Infrastructure Developers & Operators
mytable_values17 = []
url= 'https://www.screener.in/company/compare/00000032/?limit=50&page=1'
page = requests.get(url,headers = {'User-Agent':'Mozilla/5.0'})
soup=BeautifulSoup(page.content)
table_body=soup.find('table')
for row in table_body.find_all('tr'):
    col=row.find_all('td')
    col=[ele.text.strip() for ele in col]
    mytable_values17.append(col)

# %%
Infra_stock = pd.DataFrame(mytable_values17)

# %%
Infra_stock.dropna(inplace=True)
Infra_stock.columns = ['S.no','Company name','CMP(Rs)', 'P/E','Mark cap/n(Rs.Cr)','Div yeild(%)','Np qtr(Rs.Cr)', 'qtr profit(%)','Sales qtr(Rs.Cr)','qtr sales var(%)','ROCE(%)']
Infra_stock.insert(0, 'Sector', 'Infra & Dev')
del Infra_stock['S.no']

# %%
Infra_stock
# Out:
#          Sector      Company name  CMP(Rs)     P/E Mark cap/n(Rs.Cr)  \
# 1   Infra & Dev   Larsen & Toubro  1876.15   28.84         263607.36
# 2   Infra & Dev       Adani Ports   784.75   34.19         165851.01
# 3   Infra & Dev  GMR Airports Inf    34.60                  20855.00
# 4   Infra & Dev   IRB Infra.Devl.   217.05   20.07          13101.53
# 5   Infra & Dev              HFCL    76.50   37.53          10546.66
# 6   Infra & Dev             Rites   380.35   15.70           9133.25
# 7   Infra & Dev       Ircon Intl.    42.75    6.21           4020.70
# 8   Infra & Dev   Reliance Infra.   142.35                   3758.15
# 9   Infra & Dev   Engineers India    62.55   17.42           3512.77
# 10  Infra & Dev    Dilip Buildcon   217.25                   3182.30
# 11  Infra & Dev  Techno Elec.Engg   280.30   12.19           3077.27
# 12  Infra & Dev   Ashoka Buildcon    75.95    4.03           2132.09
# 13  Infra & Dev     J Kumar Infra   271.00    8.71           2051.66
# ...

# %%
#IT-Software stocks
mytable_values18 = []
url= 'https://www.screener.in/company/compare/00000034/?limit=50&page=1'
page = requests.get(url,headers = {'User-Agent':'Mozilla/5.0'})
soup=BeautifulSoup(page.content)
table_body=soup.find('table')
for row in table_body.find_all('tr'):
    col=row.find_all('td')
    col=[ele.text.strip() for ele in col]
    mytable_values18.append(col)

# %%
It_stock = pd.DataFrame(mytable_values18)

# %%
It_stock.dropna(inplace=True)
It_stock.columns = ['S.no','Company name','CMP(Rs)', 'P/E','Mark cap/n(Rs.Cr)','Div yeild(%)','Np qtr(Rs.Cr)', 'qtr profit(%)','Sales qtr(Rs.Cr)','qtr sales var(%)','ROCE(%)']
It_stock.insert(0, 'Sector', 'IT - Software')
del It_stock['S.no']

# %%
It_stock
# Out:
#            Sector      Company name  CMP(Rs)    P/E Mark cap/n(Rs.Cr)  \
# 1   IT - Software               TCS  3103.30  28.67        1135513.41
# 2   IT - Software           Infosys  1419.90  26.11         597406.71
# 3   IT - Software  HCL Technologies   982.10  19.32         266607.07
# 4   IT - Software             Wipro   379.10  18.47         208062.60
# 5   IT - Software     Tech Mahindra  1012.95  18.44          98561.63
# 6   IT - Software    L & T Infotech  4596.80  33.13          80629.90
# 7   IT - Software          Mindtree  3323.65  29.00          54827.72
# 8   IT - Software        Tata Elxsi  8312.85  83.36          51765.44
# 9   IT - Software           Mphasis  2086.60  26.30          39274.26
# 10  IT - Software    L&T Technology  3565.00  37.07          37627.65
# 11  IT - Software    Persistent Sys  3516.65  35.83          26899.55
# 12  IT - Software  Oracle Fin.Serv.  2929.95  13.62          25290.62
# ...

# %%
#Mining & Mineral products stocks
mytable_values19 = []
url= 'https://www.screener.in/company/compare/00000038/?limit=50&page=1'
page = requests.get(url,headers = {'User-Agent':'Mozilla/5.0'})
soup=BeautifulSoup(page.content)
table_body=soup.find('table')
for row in table_body.find_all('tr'):
    col=row.find_all('td')
    col=[ele.text.strip() for ele in col]
    mytable_values19.append(col)

# %%
Minin_stock = pd.DataFrame(mytable_values19)

# %%
Minin_stock.dropna(inplace=True)
Minin_stock.columns = ['S.no','Company name','CMP(Rs)', 'P/E','Mark cap/n(Rs.Cr)','Div yeild(%)','Np qtr(Rs.Cr)', 'qtr profit(%)','Sales qtr(Rs.Cr)','qtr sales var(%)','ROCE(%)']
Minin_stock.insert(0, 'Sector', 'Mining & Mineral')
del Minin_stock['S.no']

# %%
Minin_stock
# Out:
#               Sector      Company name  CMP(Rs)      P/E Mark cap/n(Rs.Cr)  \
# 1   Mining & Mineral        Coal India   234.55     6.28         144515.66
# 2   Mining & Mineral           Vedanta   293.00     5.67         108951.75
# 3   Mining & Mineral              NMDC   129.00     4.93          37819.29
# 4   Mining & Mineral             KIOCL   185.20   208.71          11207.58
# 5   Mining & Mineral           G M D C   139.85     6.24           4444.05
# 6   Mining & Mineral              MOIL   151.05     7.43           3072.63
# 7   Mining & Mineral    Maithan Alloys   941.80     2.75           2742.45
# 8   Mining & Mineral  Sandur Manganese   705.90     3.40           1906.34
# 9   Mining & Mineral   Orissa Minerals  2772.60  1211.97           1660.40
# 10  Mining & Mineral     Indian Metals   250.65     2.49           1352.36
# 11  Mining & Mineral  Ashapura Minech.    88.70    13.29            814.68
# ...

# %%
#Power Generation & Distribution stocks
mytable_values20 = []
url= 'https://www.screener.in/company/compare/00000049/?limit=50&page=1'
page = requests.get(url,headers = {'User-Agent':'Mozilla/5.0'})
soup=BeautifulSoup(page.content)
table_body=soup.find('table')
for row in table_body.find_all('tr'):
    col=row.find_all('td')
    col=[ele.text.strip() for ele in col]
    mytable_values20.append(col)

# %%
Power_stock = pd.DataFrame(mytable_values20)

# %%
Power_stock.dropna(inplace=True)
Power_stock.columns = ['S.no','Company name','CMP(Rs)', 'P/E','Mark cap/n(Rs.Cr)','Div yeild(%)','Np qtr(Rs.Cr)', 'qtr profit(%)','Sales qtr(Rs.Cr)','qtr sales var(%)','ROCE(%)']
Power_stock.insert(0, 'Sector', 'Power gen & Distr')
del Power_stock['S.no']

# %%
Power_stock
# Out:
#                Sector      Company name  CMP(Rs)     P/E Mark cap/n(Rs.Cr)  \
# 1   Power gen & Distr  Adani Transmissi  3121.10  371.75         348571.92
# 2   Power gen & Distr       Adani Green  2083.35  664.01         330064.44
# 3   Power gen & Distr              NTPC   164.75    9.29         159849.45
# 4   Power gen & Distr  Power Grid Corpn   213.95   10.38         149205.21
# 5   Power gen & Distr       Adani Power   346.85   14.22         133871.73
# 6   Power gen & Distr    Tata Power Co.   216.15   32.20          69067.27
# 7   Power gen & Distr        JSW Energy   320.20   26.49          52657.89
# 8   Power gen & Distr          NHPC Ltd    37.90   10.40          38019.99
# 9   Power gen & Distr     Torrent Power   479.55   12.06          23055.12
# 10  Power gen & Distr              SJVN    32.60   10.15          12811.13
# 11  Power gen & Distr              CESC    77.95    7.53          10339.41
# ...

# %% [markdown]
# final_df = Agro_chem.merge(Alco_stocks,on='Sector').merge(Auto_stock,on='Sector').merge(Bank_stock,on='Sector').merge(Cement_stock,on='Sector').merge(Chem_stock,on='Sector').merge(Construc_stock,on='Sector').merge(Crude_stock,on='Sector').merge(Jewel_stock,on='Sector').merge(Edoil_stock,on='Sector').merge(Engi_stock,on='Sector').merge(Ente_stock,on='Sector').merge(Ferti_stock,on='Sector').merge(Fin_stock,on='Sector').merge(Health_stock,on='Sector').merge(Hotel_stock,on='Sector').merge(Infra_stock,on='Sector').merge(It_stock,on='Sector').merge(Minin_stock,on='Sector').merge(Power_stock,on='Sector')

# %%
final_df = Agro_chem.append(Alco_stocks).append(Auto_stock).append(Bank_stock).append(Cement_stock).append(Chem_stock).append(Construc_stock).append(Crude_stock).append(Jewel_stock).append(Edoil_stock).append(Engi_stock).append(Ente_stock).append(Ferti_stock).append(Fin_stock).append(Health_stock).append(Hotel_stock).append(Infra_stock).append(It_stock).append(Minin_stock).append(Power_stock)

# %%
final_df
# Out:
#                Sector      Company name   CMP(Rs)     P/E Mark cap/n(Rs.Cr)  \
# 1       Agro Chemical               UPL    663.90   12.56          50740.04
# 2       Agro Chemical    P I Industries   2994.25   49.44          45435.00
# 3       Agro Chemical   Sumitomo Chemi.    508.05   54.43          25364.16
# 4       Agro Chemical   Bayer Crop Sci.   4648.25   32.03          20887.32
# 5       Agro Chemical    Bharat Rasayan  10899.15   25.26           4534.33
# ..                ...               ...       ...     ...               ...
# 22  Power gen & Distr   Waaree Renewab.    490.60   48.15           1021.18
# 23  Power gen & Distr      Orient Green      8.55   62.08            641.87
# 24  Power gen & Distr       K.P. Energy    409.65   15.83            455.33
# 25  Power gen & Distr      Solex Energy    313.50  253.33            250.80
# 26  Power gen & Distr  Sunedison Infra.    437.65                    196.50
#
# ...

# %%
final_df.reset_index(inplace=True)
#del final_df['index']
final_df
# Out:
#      index             Sector      Company name   CMP(Rs)     P/E  \
# 0        1      Agro Chemical               UPL    663.90   12.56
# 1        2      Agro Chemical    P I Industries   2994.25   49.44
# 2        3      Agro Chemical   Sumitomo Chemi.    508.05   54.43
# 3        4      Agro Chemical   Bayer Crop Sci.   4648.25   32.03
# 4        5      Agro Chemical    Bharat Rasayan  10899.15   25.26
# ..     ...                ...               ...       ...     ...
# 463     22  Power gen & Distr   Waaree Renewab.    490.60   48.15
# 464     23  Power gen & Distr      Orient Green      8.55   62.08
# 465     24  Power gen & Distr       K.P. Energy    409.65   15.83
# 466     25  Power gen & Distr      Solex Energy    313.50  253.33
# 467     26  Power gen & Distr  Sunedison Infra.    437.65
#
#     Mark cap/n(Rs.Cr) Div yeild(%) Np qtr(Rs.Cr) qtr profit(%)  \
# 0            50740.04         1.51       1005.00         30.09
# ...

# %%
final_df.isnull().sum()
# Out:
# index                0
# Sector               0
# Company name         0
# CMP(Rs)              0
# P/E                  0
# Mark cap/n(Rs.Cr)    0
# Div yeild(%)         0
# Np qtr(Rs.Cr)        0
# qtr profit(%)        0
# Sales qtr(Rs.Cr)     0
# qtr sales var(%)     0
# ROCE(%)              0
# dtype: int64

# %%
final_df[final_df.isnull()]
# Out:
#      index Sector Company name CMP(Rs)  P/E Mark cap/n(Rs.Cr) Div yeild(%)  \
# 0      NaN    NaN          NaN     NaN  NaN               NaN          NaN
# 1      NaN    NaN          NaN     NaN  NaN               NaN          NaN
# 2      NaN    NaN          NaN     NaN  NaN               NaN          NaN
# 3      NaN    NaN          NaN     NaN  NaN               NaN          NaN
# 4      NaN    NaN          NaN     NaN  NaN               NaN          NaN
# ..     ...    ...          ...     ...  ...               ...          ...
# 463    NaN    NaN          NaN     NaN  NaN               NaN          NaN
# 464    NaN    NaN          NaN     NaN  NaN               NaN          NaN
# 465    NaN    NaN          NaN     NaN  NaN               NaN          NaN
# 466    NaN    NaN          NaN     NaN  NaN               NaN          NaN
# 467    NaN    NaN          NaN     NaN  NaN               NaN          NaN
#
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 468 entries, 0 to 467
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              468 non-null    int64
#  1   Sector             468 non-null    object
#  2   Company name       468 non-null    object
#  3   CMP(Rs)            468 non-null    object
#  4   P/E                468 non-null    object
#  5   Mark cap/n(Rs.Cr)  468 non-null    object
#  6   Div yeild(%)       468 non-null    object
#  7   Np qtr(Rs.Cr)      468 non-null    object
#  8   qtr profit(%)      468 non-null    object
#  9   Sales qtr(Rs.Cr)   468 non-null    object
#  10  qtr sales var(%)   468 non-null    object
#  11  ROCE(%)            468 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 44.0+ KB

# %%
final_df.describe()
# Out:
#             index
# count  468.000000
# mean    12.989316
# std      7.573614
# min      1.000000
# 25%      6.000000
# 50%     12.500000
# 75%     20.000000
# max     26.000000

# %%
voidspace_index = []
for i in final_df[final_df['P/E'] == ''].index:
    voidspace_index.append(int(i))
for o in final_df[final_df['Np qtr(Rs.Cr)'] == ''].index:
    voidspace_index.append(int(o))
for p in final_df[final_df['qtr profit(%)'] == ''].index:
    voidspace_index.append(int(p))
for j in final_df[final_df['Sales qtr(Rs.Cr)'] == ''].index:
    voidspace_index.append(int(j))
for k in final_df[final_df['qtr sales var(%)'] == ''].index:
    voidspace_index.append(int(k))
for l in final_df[final_df['ROCE(%)'] == ''].index:
    voidspace_index.append(int(l))

voidspace_index1 = set(voidspace_index)
str(voidspace_index1)
# Out:
# '{21, 22, 34, 35, 37, 38, 40, 41, 42, 43, 46, 53, 56, 58, 59, 60, 61, 86, 94, 103, 105, 106, 147, 149, 151, 166, 172, 184, 187, 190, 201, 203, 209, 219, 222, 223, 231, 233, 236, 239, 241, 245, 248, 252, 257, 258, 262, 264, 267, 284, 285, 291, 292, 329, 338, 341, 345, 346, 356, 363, 365, 366, 367, 370, 375, 377, 382, 383, 384, 387, 389, 390, 391, 392, 432, 437, 439, 440, 442, 456, 458, 462, 466, 467}'

# %%
len(voidspace_index1)
# Out:
# 84

# %%
final_df.iloc[21]
# Out:
# index                             23
# Sector                 Agro Chemical
# Company name         Super Crop Safe
# CMP(Rs)                         6.10
# P/E
# Mark cap/n(Rs.Cr)              24.53
# Div yeild(%)                    0.00
# Np qtr(Rs.Cr)                  -0.37
# qtr profit(%)                  62.63
# Sales qtr(Rs.Cr)                4.29
# qtr sales var(%)              -33.18
# ROCE(%)                       -11.59
# Name: 21, dtype: object

# %%
final_df['P/E']
# Out:
# 0       12.56
# 1       49.44
# 2       54.43
# 3       32.03
# 4       25.26
#         ...
# 463     48.15
# 464     62.08
# 465     15.83
# 466    253.33
# 467
# Name: P/E, Length: 468, dtype: object

# %%
final_df
# Out:
#      index             Sector      Company name   CMP(Rs)     P/E  \
# 0        1      Agro Chemical               UPL    663.90   12.56
# 1        2      Agro Chemical    P I Industries   2994.25   49.44
# 2        3      Agro Chemical   Sumitomo Chemi.    508.05   54.43
# 3        4      Agro Chemical   Bayer Crop Sci.   4648.25   32.03
# 4        5      Agro Chemical    Bharat Rasayan  10899.15   25.26
# ..     ...                ...               ...       ...     ...
# 463     22  Power gen & Distr   Waaree Renewab.    490.60   48.15
# 464     23  Power gen & Distr      Orient Green      8.55   62.08
# 465     24  Power gen & Distr       K.P. Energy    409.65   15.83
# 466     25  Power gen & Distr      Solex Energy    313.50  253.33
# 467     26  Power gen & Distr  Sunedison Infra.    437.65
#
#     Mark cap/n(Rs.Cr) Div yeild(%) Np qtr(Rs.Cr) qtr profit(%)  \
# 0            50740.04         1.51       1005.00         30.09
# ...

# %%
final_df.to_csv(r'C:\Users\K.V.N\Desktop\Data Science\Python\Untitled Folder\scrapped_df.csv')
